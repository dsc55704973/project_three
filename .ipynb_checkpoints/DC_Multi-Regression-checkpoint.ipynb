# %% [markdown]
# # Daniel Carrillo's Jupyter Notebook

# %% [markdown]
# Dependencies

# %%
# STANDARD
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# SKYLEARN
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# DUMMY ENCODING
import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# 1. Section to load data

# %%
# dropped annual and quarterly
df = pd.read_csv('data/all_data.csv')
df.head()
# Out:
#          Date  CS_Mnth  CS_Qtr  CS_Ann  CD_Mnth  CD_Qtr  CD_Ann  Enrgy_Mnth  \
# 0  1998-12-01      NaN     NaN     NaN      NaN     NaN     NaN         NaN
# 1  1999-01-01   0.0580     NaN     NaN   0.0333     NaN     NaN     -0.0013
# 2  1999-02-01  -0.0143     NaN     NaN   0.0550     NaN     NaN     -0.0631
# 3  1999-03-01  -0.0208  0.0211     NaN  -0.0136  0.0753     NaN     -0.0064
# 4  1999-04-01   0.0112 -0.0240     NaN   0.0563  0.0992     NaN      0.1363
#
#    Enrgy_Qtr  Enrgy_Ann  ...  PPI_Commodity  Imp_Exp _Indx  haircut_price  \
# 0        NaN        NaN  ...            NaN           91.0          102.7
# 1        NaN        NaN  ...            NaN           91.3          103.0
# 2        NaN        NaN  ...            NaN           91.2          103.3
# 3    -0.0704        NaN  ...            NaN           91.5          103.7
# 4     0.0577        NaN  ...            NaN           92.4          103.9
#
#    cardboard_pice  Superbowl  Cosmetics_index  bodies  unidentified_bodies  \
# 0           166.5        AFC            160.8     2.0                 17.0
# 1           165.0        AFC            162.1     3.0                 24.0
# 2           164.5        AFC            162.1     1.0                 17.0
# 3           164.6        AFC            163.6     1.0                 16.0
# 4           171.3        AFC            163.0     4.0                 19.0
#
#    underwear  beer_prct_change
# 0        NaN               0.8
# 1        NaN              -1.1
# 2        NaN               0.6
# 3        NaN              -0.6
# 4        NaN               3.4
#
# [5 rows x 42 columns]

# %% [markdown]
# 3. Data pre-processing (convert to binary using Dummy Encoding)

# %%
# X = df[["column1", "column2", "column3"]]
# y = df["weight"].values.reshape(-1, 1)
# print(X.shape, y.shape)

# data = X.copy()

# data_binary_encoded = pd.get_dummies(data)
# data_binary_encoded.head()

# %% [markdown]
# 4. Scale and normalize

# %%
# X = pd.get_dummies(X)

# X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# X_train.head()


# // STANDARD SCALER
# X_scaler = StandardScaler().fit(X_train)
# y_scaler = StandardScaler().fit(y_train)

# X_train_scaled = X_scaler.transform(X_train)
# X_test_scaled = X_scaler.transform(X_test)
# y_train_scaled = y_scaler.transform(y_train)
# y_test_scaled = y_scaler.transform(y_test)

# %% [markdown]
# 5. Linear or non-linear regression models here (testing/training and predictions).
#     A simple linear model could be used for stock price predictions.

# %%
df = pd.read_csv('data/all_data.csv')
df.head()
df.fillna(0,inplace=True)

# %%
df.corr()
# Out:
#                        CS_Mnth    CS_Qtr    CS_Ann   CD_Mnth    CD_Qtr  \
# CS_Mnth               1.000000  0.552069  0.247979  0.607939  0.324033
# CS_Qtr                0.552069  1.000000  0.438486  0.297031  0.605289
# CS_Ann                0.247979  0.438486  1.000000  0.103243  0.226239
# CD_Mnth               0.607939  0.297031  0.103243  1.000000  0.490941
# CD_Qtr                0.324033  0.605289  0.226239  0.490941  1.000000
# CD_Ann                0.180381  0.326324  0.659549  0.250095  0.437021
# Enrgy_Mnth            0.428523  0.176023  0.062286  0.555899  0.276030
# Enrgy_Qtr             0.244905  0.399550  0.165378  0.224981  0.508341
# Enrgy_Ann             0.083775  0.145740  0.411542  0.018717  0.037335
# Fncl_Mnth             0.616143  0.347469  0.093648  0.795827  0.443396
# Util_Qtr              ...    0.048640   0.083519       0.096093
# Util_Ann              ...    0.095751   0.176761       0.202066
# Unempl                ...    0.267697   0.173136       0.242726
# Jobs_Non-Farm (000s)  ...    0.655904   0.786058       0.606528
# Hrly_Wages            ...    1.000000   0.922220       0.787610
# CPI_urban             ...    0.922220   1.000000       0.876482
# PPI_Commodity         ...    0.787610   0.876482       1.000000
# Imp_Exp _Indx         ...    0.838608   0.784680       0.713022
# haircut_price         ...    0.906273   0.992752       0.850701
# cardboard_pice        ...    0.906159   0.984379       0.892711
# Cosmetics_index       ...    0.896647   0.891283       0.845927
# bodies                ...    0.446991   0.552170       0.448172
# unidentified_bodies   ...    0.245027   0.326710       0.248265
# beer_prct_change      ...    0.019391   0.054548       0.037889
#
#                       Imp_Exp _Indx  haircut_price  cardboard_pice  \
# CS_Mnth                    0.113197       0.080391        0.076507
# CS_Qtr                     0.219369       0.154214        0.139423
# CS_Ann                     0.446037       0.272889        0.284667
# CD_Mnth                    0.039989       0.073738        0.065842
# CD_Qtr                     0.103270       0.140860        0.120927
# CD_Ann                     0.302796       0.264201        0.279715
# Enrgy_Mnth                -0.019082      -0.115217       -0.115447
# Enrgy_Qtr                  0.006049      -0.193658       -0.200354
# Enrgy_Ann                  0.105527      -0.289665       -0.272111
# Fncl_Mnth                  0.000145       0.008281        0.013403
# Fncl_Qtr                   0.024890       0.018642        0.021796
# Fncl_Ann                   0.089480       0.064644        0.116954
# HlthC_Mnth                 0.072223       0.055473        0.064253
# HlthC_Qtr                  0.164998       0.125990        0.132345
# HlthC_Ann                  0.432493       0.307432        0.363662
# Indstrl_Mnth               0.022987       0.021109        0.017032
# Indstrl_Qtr                0.085661       0.041771        0.032382
# Indstrl_Ann                0.282350       0.113703        0.154420
# Mtrls_Mnth                -0.014269       0.007135       -0.007857
# Mtrls_Qtr                  0.025575       0.021194       -0.010528
# Mtrls_Ann                  0.175712       0.043908        0.035163
# Tech_Mnth                  0.057542       0.105976        0.093127
# Tech_Qtr                   0.145259       0.212140        0.183068
# Tech_Ann                   0.336445       0.354235        0.348662
# Util_Mnth                  0.061275       0.046153        0.045488
# Util_Qtr                   0.116995       0.070434        0.065441
# Util_Ann                   0.237507       0.146184        0.144240
# Unempl                     0.379372       0.172502        0.114413
# Jobs_Non-Farm (000s)       0.416306       0.793159        0.810079
# Hrly_Wages                 0.838608       0.906273        0.906159
# CPI_urban                  0.784680       0.992752        0.984379
# PPI_Commodity              0.713022       0.850701        0.892711
# Imp_Exp _Indx              1.000000       0.723075        0.741752
# haircut_price              0.723075       1.000000        0.977481
# cardboard_pice             0.741752       0.977481        1.000000
# Cosmetics_index            0.844447       0.852619        0.884076
# bodies                     0.183253       0.594155        0.558542
# unidentified_bodies        0.181390       0.333519        0.312017
# beer_prct_change           0.016373       0.059413        0.046763
#
#                       Cosmetics_index    bodies  unidentified_bodies  \
# CS_Mnth                      0.076344 -0.065096            -0.036411
# CS_Qtr                       0.162744 -0.096212             0.006205
# CS_Ann                       0.334487  0.021966             0.082876
# CD_Mnth                      0.051585 -0.084048            -0.011125
# CD_Qtr                       0.116418 -0.083782             0.001451
# CD_Ann                       0.291008 -0.008609             0.058309
# Enrgy_Mnth                  -0.067535 -0.274539            -0.058554
# Enrgy_Qtr                   -0.114148 -0.363315            -0.055005
# Enrgy_Ann                   -0.179515 -0.375286            -0.084392
# Fncl_Mnth                    0.016760 -0.151909            -0.000421
# Fncl_Qtr                     0.047777 -0.148179             0.042019
# Fncl_Ann                     0.096103 -0.035822             0.039636
# HlthC_Mnth                   0.055588 -0.036521            -0.008776
# HlthC_Qtr                    0.131973 -0.080742             0.038119
# HlthC_Ann                    0.364822  0.033584             0.109093
# Indstrl_Mnth                 0.012097 -0.162686            -0.063653
# Indstrl_Qtr                  0.051704 -0.170295            -0.031446
# Indstrl_Ann                  0.166037 -0.088650             0.027836
# Mtrls_Mnth                  -0.013478 -0.108990            -0.044985
# Mtrls_Qtr                   -0.004453 -0.149775            -0.008331
# Mtrls_Ann                    0.041420 -0.100943             0.065751
# Tech_Mnth                    0.071219 -0.004100             0.063741
# Tech_Qtr                     0.155238  0.048215             0.118350
# Tech_Ann                     0.290087  0.182301             0.167594
# Util_Mnth                    0.044551 -0.131330            -0.045988
# Util_Qtr                     0.078073 -0.108756             0.008274
# Util_Ann                     0.135528  0.025314             0.147487
# Unempl                       0.289037  0.137268            -0.001058
# Jobs_Non-Farm (000s)         0.592152  0.461074             0.315310
# Hrly_Wages                   0.896647  0.446991             0.245027
# CPI_urban                    0.891283  0.552170             0.326710
# PPI_Commodity                0.845927  0.448172             0.248265
# Imp_Exp _Indx                0.844447  0.183253             0.181390
# haircut_price                0.852619  0.594155             0.333519
# cardboard_pice               0.884076  0.558542             0.312017
# Cosmetics_index              1.000000  0.336187             0.197788
# bodies                       0.336187  1.000000             0.391238
# unidentified_bodies          0.197788  0.391238             1.000000
# beer_prct_change             0.006923 -0.021813             0.080878
#
#                       beer_prct_change
# CS_Mnth                       0.089817
# CS_Qtr                        0.047105
# CS_Ann                        0.078528
# CD_Mnth                       0.131659
# CD_Qtr                        0.013956
# CD_Ann                        0.030413
# Enrgy_Mnth                    0.167648
# Enrgy_Qtr                    -0.009197
# Enrgy_Ann                     0.011751
# Fncl_Mnth                     0.088722
# Fncl_Qtr                      0.022374
# Fncl_Ann                      0.037316
# HlthC_Mnth                    0.057929
# HlthC_Qtr                     0.018515
# HlthC_Ann                     0.035412
# Indstrl_Mnth                  0.063752
# Indstrl_Qtr                   0.000425
# Indstrl_Ann                   0.013011
# Mtrls_Mnth                    0.103690
# Mtrls_Qtr                     0.028926
# Mtrls_Ann                     0.008614
# Tech_Mnth                     0.120853
# Tech_Qtr                      0.066929
# Tech_Ann                      0.087488
# Util_Mnth                     0.019310
# Util_Qtr                      0.021154
# Util_Ann                      0.055502
# Unempl                       -0.067813
# Jobs_Non-Farm (000s)          0.097349
# Hrly_Wages                    0.019391
# CPI_urban                     0.054548
# PPI_Commodity                 0.037889
# Imp_Exp _Indx                 0.016373
# haircut_price                 0.059413
# cardboard_pice                0.046763
# Cosmetics_index               0.006923
# bodies                       -0.021813
# unidentified_bodies           0.080878
# beer_prct_change              1.000000
#
# [39 rows x 39 columns]

# %%
# Assign the data to X and y
X = df[["CPI_urban"]]
y = df["haircut_price"].values.reshape(-1, 1)
print(X.shape, y.shape)
# Out:
# (263, 1) (263, 1)

# %%
#  train, test, split
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
#  model
model = LinearRegression()

# %%
# Fit the model to the training data and calculate the scores for the training and testing data
model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# Training Score: 0.9854858607800694
# Testing Score: 0.9856878361495239

# %%
# plot model
plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="blue", label="Training Data")
plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y.min(), xmax=y.max())
plt.title("Residual Plot")
# Out:
# Text(0.5, 1.0, 'Residual Plot')
