# %%
# STANDARD
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# SKYLEARN
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
import numpy as np

# DUMMY ENCODING
import warnings
warnings.simplefilter('ignore')

# %%
# Read CSV, zero all NaN
data = pd.read_csv('data/all_data.csv')
data = data.fillna(0)
data.head()
# Out:
#         Date  CS_Mnth  CS_Qtr  CS_Ann  CD_Mnth  CD_Qtr  CD_Ann  Enrgy_Mnth  \
# 0  12/1/1998   0.0000  0.0000     0.0   0.0000  0.0000     0.0      0.0000
# 1   1/1/1999   0.0580  0.0000     0.0   0.0333  0.0000     0.0     -0.0013
# 2   2/1/1999  -0.0143  0.0000     0.0   0.0550  0.0000     0.0     -0.0631
# 3   3/1/1999  -0.0208  0.0211     0.0  -0.0136  0.0753     0.0     -0.0064
# 4   4/1/1999   0.0112 -0.0240     0.0   0.0563  0.0992     0.0      0.1363
#
#    Enrgy_Qtr  Enrgy_Ann  ...  PPI_Commodity  Imp_Exp _Indx  haircut_price  \
# 0     0.0000        0.0  ...            0.0           91.0          102.7
# 1     0.0000        0.0  ...            0.0           91.3          103.0
# 2     0.0000        0.0  ...            0.0           91.2          103.3
# 3    -0.0704        0.0  ...            0.0           91.5          103.7
# 4     0.0577        0.0  ...            0.0           92.4          103.9
#
#    cardboard_pice  Superbowl  Cosmetics_index  bodies  unidentified_bodies  \
# 0           166.5        AFC            160.8     2.0                   17
# 1           165.0        AFC            162.1     3.0                   24
# 2           164.5        AFC            162.1     1.0                   17
# 3           164.6        AFC            163.6     1.0                   16
# 4           171.3        AFC            163.0     4.0                   19
#
#    underwear  beer_prct_change
# 0        0.0               0.8
# 1        0.0              -1.1
# 2        0.0               0.6
# 3        0.0              -0.6
# 4        0.0               3.4
#
# [5 rows x 42 columns]

# %%
# NFL column to numeric data
nfl = []

for x in data["Superbowl"]:
    if x == 'AFC':
        fb = 0
        nfl.append(fb)
    elif x == 'AFL':
        fb = 1
        nfl.append(fb)
    elif x == 'NFC':
        fb = 2
        nfl.append(fb)
    
data["Superbowl"] = nfl

# %%
data.head()
# Out:
#         Date  CS_Mnth  CS_Qtr  CS_Ann  CD_Mnth  CD_Qtr  CD_Ann  Enrgy_Mnth  \
# 0  12/1/1998   0.0000  0.0000     0.0   0.0000  0.0000     0.0      0.0000
# 1   1/1/1999   0.0580  0.0000     0.0   0.0333  0.0000     0.0     -0.0013
# 2   2/1/1999  -0.0143  0.0000     0.0   0.0550  0.0000     0.0     -0.0631
# 3   3/1/1999  -0.0208  0.0211     0.0  -0.0136  0.0753     0.0     -0.0064
# 4   4/1/1999   0.0112 -0.0240     0.0   0.0563  0.0992     0.0      0.1363
#
#    Enrgy_Qtr  Enrgy_Ann  ...  PPI_Commodity  Imp_Exp _Indx  haircut_price  \
# 0     0.0000        0.0  ...            0.0           91.0          102.7
# 1     0.0000        0.0  ...            0.0           91.3          103.0
# 2     0.0000        0.0  ...            0.0           91.2          103.3
# 3    -0.0704        0.0  ...            0.0           91.5          103.7
# 4     0.0577        0.0  ...            0.0           92.4          103.9
#
#    cardboard_pice  Superbowl  Cosmetics_index  bodies  unidentified_bodies  \
# 0           166.5          0            160.8     2.0                   17
# 1           165.0          0            162.1     3.0                   24
# 2           164.5          0            162.1     1.0                   17
# 3           164.6          0            163.6     1.0                   16
# 4           171.3          0            163.0     4.0                   19
#
#    underwear  beer_prct_change
# 0        0.0               0.8
# 1        0.0              -1.1
# 2        0.0               0.6
# 3        0.0              -0.6
# 4        0.0               3.4
#
# [5 rows x 42 columns]

# %%
plots_data=data.drop(['Date'], axis=1)

# %%
input_cols=['CS_Qtr', 'CS_Ann', 'CD_Mnth', 'CD_Qtr', 'CD_Ann',
       'Enrgy_Mnth', 'Enrgy_Qtr', 'Enrgy_Ann', 'Fncl_Mnth', 'Fncl_Qtr',
       'Fncl_Ann', 'HlthC_Mnth', 'HlthC_Qtr', 'HlthC_Ann', 'Indstrl_Mnth',
       'Indstrl_Qtr', 'Indstrl_Ann', 'Mtrls_Mnth', 'Mtrls_Qtr', 'Mtrls_Ann',
       'Tech_Mnth', 'Tech_Qtr', 'Tech_Ann', 'Util_Mnth', 'Util_Qtr',
       'Util_Ann', 'Unempl', 'Jobs_Non-Farm (000s)', 'Hrly_Wages', 'CPI_urban',
       'PPI_Commodity', 'Imp_Exp _Indx', 'haircut_price', 'cardboard_pice',
       'Superbowl', 'Cosmetics_index', 'bodies', 'unidentified_bodies',
       'underwear', 'beer_prct_change']
input_df=plots_data[input_cols]
target=plots_data['CS_Mnth']
predicted=[]
from sklearn.tree import DecisionTreeRegressor
initial_train=50
num_runs=len(input_df)-initial_train
for each_cycle in range(num_runs):
    dtr=DecisionTreeRegressor()
    dtr.fit(input_df.iloc[:initial_train+each_cycle, :], target[:initial_train+each_cycle])
    prediction=dtr.predict([input_df.iloc[initial_train+each_cycle, :]])
    print(f'Predict: {prediction} when actual is {target[initial_train+each_cycle]}')
    predicted.append(prediction)
# Out:
# Predict: [-0.0045] when actual is -0.0335
# Predict: [-0.0031] when actual is -0.0295
# Predict: [-0.0335] when actual is -0.0224
# Predict: [0.0405] when actual is 0.0392
# Predict: [-0.031] when actual is 0.0593
# Predict: [0.0318] when actual is -0.0094
# Predict: [0.058] when actual is -0.0025
# Predict: [0.0252] when actual is 0.024
# Predict: [-0.07] when actual is -0.0049
# Predict: [0.0346] when actual is 0.0492
# Predict: [0.0492] when actual is 0.0033
# Predict: [0.0593] when actual is 0.0159
# Predict: [0.0159] when actual is 0.0014
# Predict: [0.0011] when actual is 0.0615
# Predict: [-0.0176] when actual is -0.0125
# Predict: [0.0375] when actual is 0.0206
# Predict: [0.0127] when actual is -0.0107
# Predict: [0.024] when actual is 0.0039
# Predict: [0.0206] when actual is -0.0553
# Predict: [0.0014] when actual is 0.021
# Predict: [0.0161] when actual is -0.0296
# Predict: [0.0492] when actual is 0.0069
# Predict: [0.0492] when actual is 0.0248
# Predict: [0.021] when actual is 0.0425
# Predict: [0.0014] when actual is 0.0043
# Predict: [0.0248] when actual is 0.0017
# Predict: [0.0008] when actual is -0.0102
# Predict: [0.] when actual is -0.0142
# Predict: [-0.01045] when actual is 0.0188
# Predict: [0.0017] when actual is -0.0193
# Predict: [-0.0107] when actual is 0.0289
# Predict: [-0.0193] when actual is -0.0162
# Predict: [0.0069] when actual is 0.003
# Predict: [-0.07] when actual is 0.0056
# Predict: [0.0307] when actual is 0.0116
# Predict: [-0.0102] when actual is -0.0123
# Predict: [0.0115] when actual is -0.0021
# Predict: [-0.0021] when actual is 0.0168
# Predict: [-0.0021] when actual is 0.0042
# Predict: [0.0033] when actual is 0.0059
# Predict: [-0.0124] when actual is -0.0004
# Predict: [-0.00013333] when actual is 0.0151
# Predict: [-0.0102] when actual is 0.0169
# Predict: [0.0292] when actual is 0.0385
# Predict: [0.0248] when actual is -0.0156
# Predict: [-0.07] when actual is 0.0262
# Predict: [0.0043] when actual is -0.0066
# Predict: [-0.0107] when actual is 0.0148
# Predict: [0.0168] when actual is 0.0253
# Predict: [-0.0123] when actual is -0.0348
# Predict: [0.0289] when actual is 0.0322
# Predict: [0.0615] when actual is 0.0285
# Predict: [0.0615] when actual is 0.0153
# Predict: [-0.0047] when actual is -0.0245
# Predict: [0.0127] when actual is -0.0251
# Predict: [-0.0021] when actual is 0.0223
# Predict: [0.0023] when actual is 0.0318
# Predict: [0.0153] when actual is 0.0215
# Predict: [0.0215] when actual is 0.0305
# Predict: [0.0206] when actual is -0.0286
# Predict: [-0.0034] when actual is -0.0466
# Predict: [0.0056] when actual is -0.0088
# Predict: [0.0223] when actual is 0.043
# Predict: [-0.0021] when actual is -0.0107
# Predict: [0.0774] when actual is 0.0241
# Predict: [-0.0466] when actual is -0.0748
# Predict: [-0.0147] when actual is 0.0429
# Predict: [0.04295] when actual is 0.0349
# Predict: [0.0169] when actual is -0.0323
# Predict: [-0.0493] when actual is -0.1072
# Predict: [-0.1072] when actual is -0.0403
# Predict: [0.0206] when actual is 0.0148
# Predict: [-0.1072] when actual is -0.0848
# Predict: [-0.0403] when actual is -0.0808
# Predict: [-0.0195] when actual is 0.0422
# Predict: [0.0986] when actual is 0.0515
# Predict: [0.0986] when actual is 0.0575
# Predict: [0.01505] when actual is -0.0107
# Predict: [0.0492] when actual is 0.0667
# Predict: [0.0575] when actual is 0.0032
# Predict: [0.0774] when actual is 0.0275
# Predict: [-0.0348] when actual is 0.0173
# Predict: [0.058] when actual is 0.0453
# Predict: [0.0262] when actual is -0.0204
# Predict: [-0.0248] when actual is -0.0034
# Predict: [0.043] when actual is 0.0292
# Predict: [0.0223] when actual is 0.0343
# Predict: [0.032] when actual is -0.0143
# Predict: [-0.0034] when actual is -0.0506
# Predict: [0.] when actual is -0.0278
# Predict: [0.0453] when actual is 0.0678
# Predict: [-0.0004] when actual is -0.018000000000000002
# Predict: [0.0678] when actual is 0.0426
# Predict: [0.0349] when actual is 0.0348
# Predict: [-0.0143] when actual is -0.0118
# Predict: [0.04275] when actual is 0.0312
# Predict: [0.0262] when actual is -0.0146
# Predict: [0.0188] when actual is 0.028999999999999998
# Predict: [-0.0107] when actual is 0.004
# Predict: [0.0615] when actual is 0.0547
# Predict: [0.004] when actual is 0.0212
# Predict: [0.0349] when actual is -0.0341
# Predict: [-0.0034] when actual is -0.0016
# Predict: [-0.0553] when actual is -0.0071
# Predict: [-0.0748] when actual is -0.046
# Predict: [0.0492] when actual is 0.0356
# Predict: [0.0292] when actual is 0.0468
# Predict: [-0.0107] when actual is 0.0228
# Predict: [0.03095] when actual is -0.0162
# Predict: [0.0228] when actual is 0.0339
# Predict: [0.0173] when actual is 0.025
# Predict: [0.004] when actual is 0.0029
# Predict: [0.0212] when actual is -0.0211
# Predict: [0.0575] when actual is 0.035
# Predict: [-0.0286] when actual is 0.0335
# Predict: [0.02895] when actual is -0.0078
# Predict: [-0.0078] when actual is 0.0093
# Predict: [0.0069] when actual is -0.0106
# Predict: [-0.0078] when actual is 0.0155
# Predict: [0.0158] when actual is -0.0169
# Predict: [0.016] when actual is 0.0486
# Predict: [-0.0204] when actual is 0.021
# Predict: [0.0486] when actual is 0.0483
# Predict: [0.0285] when actual is 0.0292
# Predict: [-0.0156] when actual is -0.0181
# Predict: [-0.0506] when actual is -0.006
# Predict: [0.0343] when actual is 0.0423
# Predict: [-0.0506] when actual is -0.0459
# Predict: [-0.0181] when actual is 0.0023
# Predict: [0.003] when actual is 0.0649
# Predict: [-0.0078] when actual is 0.0158
# Predict: [-0.0169] when actual is -0.0042
# Predict: [-0.0142] when actual is -0.0499
# Predict: [0.0423] when actual is 0.0319
# Predict: [-0.01065] when actual is 0.0238
# Predict: [0.0029] when actual is 0.0265
# Predict: [0.0168] when actual is 0.0183
# Predict: [0.0265] when actual is -0.006
# Predict: [-0.0459] when actual is -0.036000000000000004
# Predict: [0.0423] when actual is 0.0487
# Predict: [0.0056] when actual is -0.0024
# Predict: [0.0547] when actual is 0.0348
# Predict: [0.0348] when actual is 0.0523
# Predict: [0.0292] when actual is -0.0094
# Predict: [-0.0459] when actual is -0.0105
# Predict: [0.01595] when actual is 0.0403
# Predict: [-0.0466] when actual is -0.0266
# Predict: [0.0023] when actual is -0.0035
# Predict: [0.0335] when actual is 0.006999999999999999
# Predict: [-0.036] when actual is -0.0198
# Predict: [0.007] when actual is 0.0497
# Predict: [-0.0463] when actual is -0.0781
# Predict: [0.043] when actual is 0.0183
# Predict: [0.0289] when actual is 0.057
# Predict: [-0.0025] when actual is -0.0078
# Predict: [0.0173] when actual is 0.0063
# Predict: [-0.0211] when actual is 0.0165
# Predict: [0.0183] when actual is 0.0111
# Predict: [0.0425] when actual is 0.0318
# Predict: [0.0148] when actual is -0.0074
# Predict: [0.021] when actual is 0.0048
# Predict: [0.0111] when actual is 0.0484
# Predict: [0.0403] when actual is -0.0107
# Predict: [0.0033] when actual is -0.0091
# Predict: [0.0252] when actual is -0.0192
# Predict: [-0.0224] when actual is -0.006
# Predict: [0.0589] when actual is -0.0456
# Predict: [-0.0106] when actual is 0.027000000000000003
# Predict: [0.043] when actual is 0.0114
# Predict: [0.0575] when actual is 0.0533
# Predict: [0.0114] when actual is -0.0085
# Predict: [0.03185] when actual is 0.011000000000000001
# Predict: [-0.0348] when actual is 0.0262
# Predict: [0.0033] when actual is -0.0305
# Predict: [-0.0107] when actual is 0.0073
# Predict: [0.02635] when actual is -0.0101
# Predict: [0.0429] when actual is -0.0153
# Predict: [0.0148] when actual is -0.0137
# Predict: [0.0318] when actual is 0.0505
# Predict: [-0.0074] when actual is 0.0182
# Predict: [-0.0651] when actual is 0.0114
# Predict: [-0.0251] when actual is -0.075
# Predict: [-0.0749] when actual is -0.0152
# Predict: [-0.0251] when actual is -0.0421
# Predict: [-0.0421] when actual is -0.0092
# Predict: [-0.0348] when actual is 0.0301
# Predict: [0.01105] when actual is 0.0411
# Predict: [0.0292] when actual is 0.0056
# Predict: [0.0182] when actual is 0.0056
# Predict: [0.0165] when actual is 0.0207
# Predict: [0.0411] when actual is 0.0241
# Predict: [-0.075] when actual is -0.1102
# Predict: [0.0356] when actual is 0.0659
# Predict: [-0.009] when actual is 0.0177
# Predict: [0.0301] when actual is 0.0316
# Predict: [0.0492] when actual is 0.0277
# Predict: [-0.0162] when actual is -0.0362
# Predict: [0.0659] when actual is 0.0481
# Predict: [-0.0305] when actual is 0.0211
# Predict: [0.0262] when actual is 0.0144
# Predict: [0.0318] when actual is 0.0164
# Predict: [0.0206] when actual is -0.0029
# Predict: [-0.01545] when actual is 0.01
# Predict: [0.0093] when actual is 0.0197
# Predict: [0.0405] when actual is 0.0049
# Predict: [-0.0691] when actual is -0.0836
# Predict: [-0.0278] when actual is -0.0881
# Predict: [0.0422] when actual is 0.0934
# Predict: [0.0318] when actual is 0.0228
# Predict: [-0.0025] when actual is -0.0086
# Predict: [0.01505] when actual is 0.0677
# Predict: [-0.0086] when actual is 0.0453
# Predict: [0.0144] when actual is -0.0168

# %%
# Out:
# 263

# %%
predictions = []
for i in range (len(predicted)):
    x = predicted[i][0]
    predictions.append(x)

# %%
Date = (data['Date'][initial_train:])
CS_Mnth = (data['CS_Mnth'][initial_train:])
len(data)
# Out:
# 263

# %%
CS = []
for i in range(initial_train, len(data)):
    x = CS_Mnth[i]
    CS.append(x)

# %%
chart = pd.DataFrame({
    'CS_Mnth_act': CS,
    'CS_Mnth_pred': predictions,
    }, index = Date)

# %%
lines = chart.plot.line()
plt.rcParams['figure.figsize'] = [14,10]
plt.ylim(bottom = -0.2, top = 0.15)
# Out:
# (-0.2, 0.15)

# %%
sector = 'CS_Mnth'
cols = data.drop(['Date', sector], axis=1).columns
cols
# Out:
# Index(['CS_Qtr', 'CS_Ann', 'CD_Mnth', 'CD_Qtr', 'CD_Ann', 'Enrgy_Mnth',
#        'Enrgy_Qtr', 'Enrgy_Ann', 'Fncl_Mnth', 'Fncl_Qtr', 'Fncl_Ann',
#        'HlthC_Mnth', 'HlthC_Qtr', 'HlthC_Ann', 'Indstrl_Mnth', 'Indstrl_Qtr',
#        'Indstrl_Ann', 'Mtrls_Mnth', 'Mtrls_Qtr', 'Mtrls_Ann', 'Tech_Mnth',
#        'Tech_Qtr', 'Tech_Ann', 'Util_Mnth', 'Util_Qtr', 'Util_Ann', 'Unempl',
#        'Jobs_Non-Farm (000s)', 'Hrly_Wages', 'CPI_urban', 'PPI_Commodity',
#        'Imp_Exp _Indx', 'haircut_price', 'cardboard_pice', 'Superbowl',
#        'Cosmetics_index', 'bodies', 'unidentified_bodies', 'underwear',
#        'beer_prct_change'],
#       dtype='object')

# %%
# chart function
def getchart(sector):
    plots_data=data.drop(['Date'], axis=1)
    cols = data.drop(['Date', sector], axis=1).columns
    inputs = []
    for i in range(len(cols)):
        inputs.append(cols[i])

    input_df=plots_data[inputs]
    target=plots_data[sector]
    predicted=[]
    from sklearn.tree import DecisionTreeRegressor
    initial_train=50
    num_runs=len(input_df)-initial_train
    for each_cycle in range(num_runs):
        dtr=DecisionTreeRegressor()
        dtr.fit(input_df.iloc[:initial_train+each_cycle, :], target[:initial_train+each_cycle])
        prediction=dtr.predict([input_df.iloc[initial_train+each_cycle, :]])
#         print(f'Predict: {prediction} when actual is {target[initial_train+each_cycle]}')
        predicted.append(prediction)
    
    predictions = []
    for i in range (len(predicted)):
        x = predicted[i][0]
        predictions.append(x)
        
    Date = (data['Date'][initial_train:])
    Sector = (data[sector][initial_train:])
    
    Actual = []
    for i in range(initial_train, len(data)):
        x = Sector[i]
        Actual.append(x)
        
    Chart = pd.DataFrame({
        'Actual': Actual,
        'Predicted': predictions,
        }, index = Date)
    
    line = Chart.plot.line()
    plt.rcParams['figure.figsize'] = [14,10]
#     plt.ylim(bottom = -0.2, top = 0.15)
    
    return line

# %%
getchart('CD_Mnth')

# %%
getchart('CD_Ann')

# %%
getchart('CD_Qtr')

# %%
getchart('Tech_Qtr')

# %%
# prediction analytics dataframe

predictions = []
for i in range (len(predicted)):
    x = predicted[i][0]
    predictions.append(x)

Date = (data['Date'][initial_train:])
Sector = (data[sector][initial_train:])

Actual = []
for i in range(initial_train, len(data)):
    x = Sector[i]
    Actual.append(x)


predictive_analytics = pd.DataFrame({
        'Date': Date,
        'Actual': Actual,
        'Predicted': predictions
    })

predictive_analytics=predictive_analytics.reset_index()
predictive_analytics=predictive_analytics.drop(columns=['index'])
predictive_analytics
# Out:
#           Date  Actual  Predicted
# 0     2/1/2003 -0.0335   -0.00450
# 1     3/1/2003 -0.0295   -0.00310
# 2     4/1/2003 -0.0224   -0.03350
# 3     5/1/2003  0.0392    0.04050
# 4     6/1/2003  0.0593   -0.03100
# ..         ...     ...        ...
# 208   6/1/2020  0.0228    0.03180
# 209   7/1/2020 -0.0086   -0.00250
# 210   8/1/2020  0.0677    0.01505
# 211   9/1/2020  0.0453   -0.00860
# 212  10/1/2020 -0.0168    0.01440
#
# [213 rows x 3 columns]

# %%
# output to csv
predictive_analytics.to_csv('Predictive Data/predictive_analytics_data.csv')
